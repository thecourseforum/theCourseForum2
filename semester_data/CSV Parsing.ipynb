# %%
import pandas as pd
import os

# %%
fall2009 = pd.read_csv('csv/2009fall.csv')

# %%
fall2009.sample(40)
# Out:
#       ClassNumber Mnemonic  Number Section               Type   Units  \
# 7271        38336     PLIR    5993      31  Independent Study       3
# 1304        35715      BME    8999      07  Independent Study  1 - 12
# 843         10707     BIOL    2030     124         Laboratory       2
# 968         38538     BIOL    4912      22  Independent Study       2
# 8428        39036      SOC    3559       3            Lecture       3
# 2827        34645     EDLF    5500       7            Lecture       1
# 3220        19269     ENWR    1505       4            Seminar       3
# 7487        14183     PSYC    3006     111         Laboratory       4
# 1660        11053     CHEM    9610       1  Independent Study  1 - 12
# 6275        16027     NUCO    3300     103         Laboratory       4
# 1049        39146     BIOL    4915      17  Independent Study       2
# 247         10361     ARAB    2010       3            Lecture       4
# ...

# %%
def clean_semester_df(df):
    df = df.dropna(subset=['ClassNumber', 'Mnemonic', 'Number'])
    
    return df

# %%
fall2009.size
# Out:
# 141104

# %%
clean_semester_df(fall2009).size
# Out:
# 141104
